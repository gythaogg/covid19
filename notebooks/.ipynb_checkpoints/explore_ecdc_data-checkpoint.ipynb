# %% [markdown]
# # Setup

# %%
LOG_PLOT = False
NDAYS=100

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
plt.style.use('seaborn-darkgrid')
import os
from helper import *
from datetime import datetime
from ecdc import ECDC

# %% [markdown]
# ## ECDC Data

# %%
ecdc = ECDC()
df = ecdc.df
print(ecdc.df.dateRep.max())
df.columns
# Out:
# 2020-11-05 00:00:00
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp',
#        'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'],
#       dtype='object')

# %% [markdown]
# ## DF Subsets

# %%
EU = df[df.continentExp=='Europe']
AMERICA = df[(df.continentExp=='America')]

# %%
ecdc.plot_selection(EU.groupby('dateRep', as_index=False).agg({'cases': sum}), ndays=250, roll_days=7, log=False)
plt.title('Cases')
plt.tight_layout()
ecdc.plot_selection(EU.groupby('dateRep', as_index=False).agg({'deaths': sum}), column='deaths',ndays=250, roll_days=7, log=False)
plt.title('Deaths')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Overview

# %% [markdown]
# ## Austria, USA, India, ...

# %%
# countries = ['AT', 'IN', 'US', 'UK', 'DE', 'NL', 'FR',  'IT', 'ES','EL' ]
countries = ('AT', 'IN', 'US', 'NL', 'UK', 'DE','ES')
SELECTION =  df[df.geoId.isin(countries)]

ecdc.plot_comparison(countries, log=False, ndays=100)
ecdc.plot_comparison(countries, field='deaths', log=False, ndays=100)

ecdc.overview(SELECTION)
# Out:
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
#                             dateRep         cases  \
#                              latest   rolling_avg
# countriesAndTerritories
# United_States_of_America 2020-11-05  89780.285714
# India                    2020-11-05  46269.000000
# United_Kingdom           2020-11-05  22397.714286
# Spain                    2020-11-04  21129.285714
# Germany                  2020-11-05  16652.857143
# Netherlands              2020-11-05   9063.142857
# Austria                  2020-11-05   4762.000000
#
#                                                                       deaths  \
#                                                  last_5_days     max     sum
# countriesAndTerritories
# United_States_of_America  78934, 81001, 83883, 92734, 102507  102507  233729
# India                      46963, 45231, 38310, 46253, 50210   97894  124315
# United_Kingdom             21915, 23254, 18950, 20018, 25177   26687   47742
# Spain                              0, 0, 55019, 18669, 25042   55019   38118
# Germany                    14177, 12097, 15352, 17214, 19990   19990   10930
# Netherlands                     9790, 8673, 8278, 7729, 7622   11102    7672
# Austria                         5141, 4526, 3160, 4445, 6514    6514    1204
#
#                                                       \
#                          last_7_days_sum rolling_avg
# countriesAndTerritories
# United_States_of_America            6029  861.285714
# India                               3788  541.142857
# United_Kingdom                      2067  295.285714
# Spain                               2652  378.857143
# Germany                              658   94.000000
# Netherlands                          480   68.571429
# Austria                              164   23.428571
#
#                                                            \
#                                         last_5_days   max
# countriesAndTerritories
# United_States_of_America  848, 440, 555, 1076, 1102  4928
# India                       470, 496, 490, 514, 704  2003
# United_Kingdom              326, 162, 136, 397, 492  1224
# Spain                          0, 0, 379, 238, 1623  1623
# Germany                       29, 49, 131, 151, 118   315
# Netherlands                    50, 39, 29, 113, 106   234
# Austria                          18, 17, 21, 34, 35    35
#
#                          Cumulative_number_for_14_days_of_COVID-19_cases_per_100000  \
#                                                                              latest
# countriesAndTerritories
# United_States_of_America                                         349.537110
# India                                                             48.092174
# United_Kingdom                                                   464.881359
# Spain                                                            594.653777
# Germany                                                          247.574016
# Netherlands                                                      753.522577
# Austria                                                          614.757684
#
#
#                                  max
# countriesAndTerritories
# United_States_of_America  349.537110
# India                      94.173835
# United_Kingdom            469.115601
# Spain                     594.653777
# Germany                   247.574016
# Netherlands               762.410353
# Austria                   614.757684

# %% [markdown]
# ## Sweden and the world

# %%
countries = ('SE', 'NZ','DE','AT','NO','DK','FI','NL','US')
ecdc.plot_comparison(countries, log=False, ndays=100)
# Out:
# <img src="data:image/png;base64,..." width="900">
# <AxesSubplot:title={'center':'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'}>

# %% [markdown]
# ### World

# %%
ecdc.overview(df).head(5)
# Out:
#                             dateRep         cases  \
#                              latest   rolling_avg
# countriesAndTerritories
# United_States_of_America 2020-11-05  89780.285714
# India                    2020-11-05  46269.000000
# France                   2020-11-05  44027.000000
# Italy                    2020-11-05  28658.714286
# United_Kingdom           2020-11-05  22397.714286
#
#                                                                       deaths  \
#                                                  last_5_days     max     sum
# countriesAndTerritories
# United_States_of_America  78934, 81001, 83883, 92734, 102507  102507  233729
# India                      46963, 45231, 38310, 46253, 50210   97894  124315
# France                     32641, 49290, 52518, 36330, 40558   52518   38674
# Italy                      31756, 29905, 22253, 28241, 30548   31756   39764
# United_Kingdom             21915, 23254, 18950, 20018, 25177   26687   47742
#
#                                                       \
#                          last_7_days_sum rolling_avg
# countriesAndTerritories
# United_States_of_America            6029  861.285714
# India                               3788  541.142857
# France                              2889  412.714286
# Italy                               1859  265.571429
# United_Kingdom                      2067  295.285714
#
#                                                            \
#                                         last_5_days   max
# countriesAndTerritories
# United_States_of_America  848, 440, 555, 1076, 1102  4928
# India                       470, 496, 490, 514, 704  2003
# France                      223, 231, 416, 854, 385  2004
# Italy                       297, 208, 233, 353, 352   971
# United_Kingdom              326, 162, 136, 397, 492  1224
#
#                          Cumulative_number_for_14_days_of_COVID-19_cases_per_100000  \
#                                                                              latest
# countriesAndTerritories
# United_States_of_America                                         349.537110
# India                                                             48.092174
# France                                                           874.309497
# Italy                                                            564.498944
# United_Kingdom                                                   464.881359
#
#
#                                  max
# countriesAndTerritories
# United_States_of_America  349.537110
# India                      94.173835
# France                    874.309497
# Italy                     564.498944
# United_Kingdom            469.115601

# %% [markdown]
# ## Fastest growth in number of cases per 100,000 in Europe

# %%
EU_med = EU[EU.popData2019>2000000]
EU_most = EU_med.sort_values(['dateRep', 'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'], ascending=[False,False]).head(10)

geoIds = EU_med.sort_values(['dateRep', 'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'], ascending=[False,False]).head(5).geoId.to_list()

ecdc.plot_comparison(['AT','DE','SE', *geoIds ], log=True, ndays=200, field='Cumulative_number_for_14_days_of_COVID-19_cases_per_100000');
ecdc.plot_comparison(['AT','DE','SE', *geoIds ], log=False, ndays=200, field='deaths', roll_days=14);

EU_most
# Out:
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 4785  2020-11-05    5     11  2020      9      33                 Belgium
# 12963 2020-11-05    5     11  2020  15731     220                 Czechia
# 47086 2020-11-05    5     11  2020  10043      72             Switzerland
# 44427 2020-11-05    5     11  2020   2025      39                Slovenia
# 2014  2020-11-05    5     11  2020   2413      28                 Armenia
# 17673 2020-11-05    5     11  2020  40558     385                  France
# 34827 2020-11-05    5     11  2020   7622     106             Netherlands
# 18686 2020-11-05    5     11  2020   2401      20                 Georgia
# 11953 2020-11-05    5     11  2020   2480      26                 Croatia
# 39378 2020-11-05    5     11  2020  24692     373                  Poland
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# 4785     BE                  BEL   11455519.0       Europe
# 12963    CZ                  CZE   10649800.0       Europe
# 47086    CH                  CHE    8544527.0       Europe
# 44427    SI                  SVN    2080908.0       Europe
# 2014     AM                  ARM    2957728.0       Europe
# 17673    FR                  FRA   67012883.0       Europe
# 34827    NL                  NLD   17282163.0       Europe
# 18686    GE                  GEO    3996762.0       Europe
# 11953    HR                  HRV    4076246.0       Europe
# 39378    PL                  POL   37972812.0       Europe
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 4785                                         1631.108988
# 12963                                        1594.405529
# 47086                                        1169.637594
# 44427                                        1125.710507
# 2014                                         1049.217507
# 17673                                         874.309497
# 34827                                         753.522577
# 18686                                         700.817312
# 11953                                         693.775596
# 39378                                         624.017521

# %% [markdown]
# # Deaths

# %% [markdown]
# ## Austria, USA and India

# %%
f,ax = plt.subplots()
countries = ('AT', 'US', 'IN')
for c in countries:
    df = ecdc.select_country(c)
    popData2019 = df.iloc[0].popData2019
    label = df.iloc[0].countriesAndTerritories.replace('_',' ')
#     ax.plot(df.dateRep, df.deaths.rolling(14).mean(), label=label)
    ax.plot(df.dateRep, df.deaths.cumsum(), label=label)

# plt.yscale('log')
pretty_plot(ax,log=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Worldwide Deaths

# %%
f, ax = plt.subplots()
deaths =ecdc.df.groupby('dateRep').agg({'deaths':'sum'})
ax.plot(deaths.index, deaths.deaths.rolling(14).mean(), label='total', c='k', linestyle='--')
continents = ecdc.df.continentExp.unique()
for c in continents:
    if c=='Other': continue
    df_deaths =ecdc.df[ecdc.df.continentExp==c].groupby('dateRep').agg({'deaths':'sum'})
    ax.plot(df_deaths.index, df_deaths.deaths.rolling(14).mean(), label=c.replace('_',' '))
    
    
pretty_plot(ax, log=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## India

# %%
ecdc.plot_country('IN', column='deaths', log=LOG_PLOT,ndays=200, roll_days=7);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## USA

# %%
ecdc.plot_country('US', column='deaths', roll_days=7);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Germany

# %%
ecdc.plot_country('DE', log=LOG_PLOT,ndays=NDAYS, roll_days=7,column='deaths');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## UK

# %%
ecdc.plot_country('UK', log=LOG_PLOT,ndays=NDAYS,roll_days=7,column='deaths');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Commit and Push

# %%
# %cd Documents/code/covid19/
now = datetime.now()
commit_message = "Last run on " + now.strftime('%Y-%m-%d %H:%M')
commit_message
! echo $commit_message > commit_message.txt
! git add .
! git commit -F commit_message.txt
! git push
# Out:
# [Errno 2] No such file or directory: 'Documents/code/covid19/'
# /home/gythaogg/Documents/code/covid19/notebooks
# [feature/angular b8a5028] Last run on 2020-10-29 15:38
#  4 files changed, 4121 insertions(+), 230 deletions(-)
# Enumerating objects: 13, done.
# Counting objects: 100% (13/13), done.
# Delta compression using up to 16 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 731.06 KiB | 9.25 MiB/s, done.
# Total 7 (delta 6), reused 0 (delta 0)
# remote: Resolving deltas: 100% (6/6), completed with 6 local objects.
# To github.com:gythaogg/covid19.git
#    f088be6..b8a5028  feature/angular -> feature/angular

# %%
! git push --set-upstream origin feature/angular
# Out:
# Branch 'feature/angular' set up to track remote branch 'feature/angular' from 'origin'.
# Everything up-to-date
