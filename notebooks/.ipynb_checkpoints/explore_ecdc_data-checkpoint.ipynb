# %% [markdown]
# # Setup

# %%
LOG_PLOT = False
NDAYS=100

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
plt.style.use('seaborn-darkgrid')
import os
from helper import *

from ecdc import ECDC

ecdc = ECDC()
df = ecdc.df

# %%
df.columns
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp',
#        'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'],
#       dtype='object')

# %% [markdown]
# ## ECDC Data

# %% [markdown]
# ## DF Subsets

# %%
EU = df[df.continentExp=='Europe']
AMERICA = df[(df.continentExp=='America')]

# %% [markdown]
# # Overview

# %% [markdown]
# ## Austria, USA, India, ...

# %%
# countries = ['AT', 'IN', 'US', 'UK', 'DE', 'NL', 'FR',  'IT', 'ES','EL' ]
countries = ('AT', 'IN', 'US', 'UK', 'NL', 'DE')
SELECTION =  df[df.geoId.isin(countries)]

ecdc.plot_comparison(countries, log=False, ndays=100)
ecdc.overview(SELECTION)
# Out:
# <img src="data:image/png;base64,..." width="900">
#                                  cases                                     \
#                            rolling_avg                        last_5_days
# countriesAndTerritories
# India                     66331.000000  66732, 55342, 63509, 67708, 63371
# United_States_of_America  53327.285714  43597, 41653, 52517, 59386, 63785
# United_Kingdom            15972.428571  12872, 13972, 17232, 19724, 18978
# Netherlands                6868.857143       6368, 6844, 7368, 7271, 7779
# Germany                    4842.428571       2467, 4122, 5132, 6638, 7334
# Austria                    1165.857143        1298, 608, 1171, 1606, 1396
#
#                                  deaths                              \
#                             max     sum last_7_days_sum rolling_avg
# countriesAndTerritories
# India                     97894  112161            5671  810.142857
# United_States_of_America  78427  217700            4927  703.857143
# United_Kingdom            22961   43293             701  100.142857
# Netherlands                7779    6683             161   23.000000
# Germany                    7334    9734             145   20.714286
# Austria                    1606     894              41    5.857143
#
#                                                          \
#                                       last_5_days   max
# countriesAndTerritories
# India                     816, 706, 730, 680, 895  2003
# United_States_of_America  394, 314, 817, 970, 828  4928
# United_Kingdom              65, 50, 143, 137, 138  1224
# Netherlands                    17, 12, 35, 32, 29   234
# Germany                         6, 13, 43, 33, 24   315
# Austria                            6, 5, 10, 9, 6    31
#
#                          Cumulative_number_for_14_days_of_COVID-19_cases_per_100000  \
#                                                                              latest
# countriesAndTerritories
# India                                                             71.456917
# United_States_of_America                                         213.353343
# United_Kingdom                                                   320.259939
# Netherlands                                                      461.435296
# Germany                                                           65.240320
# Austria                                                          163.081239
#
#
#                                  max
# countriesAndTerritories
# India                      94.173835
# United_States_of_America  282.723242
# United_Kingdom            320.259939
# Netherlands               461.435296
# Germany                    86.358323
# Austria                   163.081239

# %% [markdown]
# ## Sweden and the world

# %%
countries = ('SE', 'NZ','DE','AT','IT','NO','DK','FI','IS')
ecdc.plot_comparison(countries, log=True, ndays=100)
# Out:
# <img src="data:image/png;base64,..." width="900">
# <AxesSubplot:title={'center':'Cumulative number for 14 days of COVID-19 cases per 100000'}>

# %% [markdown]
# ## Most cases in the last 7 days

# %% [markdown]
# ### Europe

# %%
ecdc.overview(EU).head(5)
# Out:
#                                 cases                                     \
#                           rolling_avg                        last_5_days
# countriesAndTerritories
# France                   19720.857143   16101, 8505, 12993, 22591, 30621
# United_Kingdom           15972.428571  12872, 13972, 17232, 19724, 18978
# Russia                   13435.857143  13634, 13592, 13868, 14231, 13754
# Spain                    10435.714286       0, 27856, 7118, 11970, 13318
# Czechia                   6893.285714       3103, 4311, 8326, 9543, 9720
#
#                                deaths                              \
#                            max    sum last_7_days_sum rolling_avg
# countriesAndTerritories
# France                   30621  33125             604   86.285714
# United_Kingdom           22961  43293             701  100.142857
# Russia                   14231  23491            1435  205.000000
# Spain                    31785  33553             865  123.571429
# Czechia                   9720   1230             361   51.571429
#
#                                                         \
#                                      last_5_days   max
# countriesAndTerritories
# France                      46, 95, 108, 104, 88  2004
# United_Kingdom             65, 50, 143, 137, 138  1224
# Russia                   143, 125, 244, 239, 286   312
# Spain                       0, 195, 80, 209, 140  1179
# Czechia                       39, 17, 55, 66, 58    90
#
#                         Cumulative_number_for_14_days_of_COVID-19_cases_per_100000  \
#                                                                             latest
# countriesAndTerritories
# France                                                          346.469201
# United_Kingdom                                                  320.259939
# Russia                                                          115.808174
# Spain                                                           304.166899
# Czechia                                                         701.938065
#
#
#                                 max
# countriesAndTerritories
# France                   346.469201
# United_Kingdom           320.259939
# Russia                   115.808174
# Spain                    330.240113
# Czechia                  701.938065

# %% [markdown]
# ### World

# %%
ecdc.overview(df).head(5)
# Out:
#                                  cases                                     \
#                            rolling_avg                        last_5_days
# countriesAndTerritories
# India                     66331.000000  66732, 55342, 63509, 67708, 63371
# United_States_of_America  53327.285714  43597, 41653, 52517, 59386, 63785
# Brazil                    20134.571429   12345, 8426, 10220, 27235, 28523
# France                    19720.857143   16101, 8505, 12993, 22591, 30621
# United_Kingdom            15972.428571  12872, 13972, 17232, 19724, 18978
#
#                                  deaths                              \
#                             max     sum last_7_days_sum rolling_avg
# countriesAndTerritories
# India                     97894  112161            5671  810.142857
# United_States_of_America  78427  217700            4927  703.857143
# Brazil                    69074  152460            3503  500.428571
# France                    30621   33125             604   86.285714
# United_Kingdom            22961   43293             701  100.142857
#
#                                                          \
#                                       last_5_days   max
# countriesAndTerritories
# India                     816, 706, 730, 680, 895  2003
# United_States_of_America  394, 314, 817, 970, 828  4928
# Brazil                    290, 201, 309, 749, 713  1595
# France                       46, 95, 108, 104, 88  2004
# United_Kingdom              65, 50, 143, 137, 138  1224
#
#                          Cumulative_number_for_14_days_of_COVID-19_cases_per_100000  \
#                                                                              latest
# countriesAndTerritories
# India                                                             71.456917
# United_States_of_America                                         213.353343
# Brazil                                                           152.710132
# France                                                           346.469201
# United_Kingdom                                                   320.259939
#
#
#                                  max
# countriesAndTerritories
# India                      94.173835
# United_States_of_America  282.723242
# Brazil                    304.320523
# France                    346.469201
# United_Kingdom            320.259939

# %% [markdown]
# # Austria
# Compare ECDC data with Gesundheitsminesterium Data

# %% [markdown]
# ## Plots

# %%
ecdc.plot_country('AT', log=LOG_PLOT, ndays=100, roll_days=10);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # India

# %%
ecdc.plot_country('IN', log=LOG_PLOT,ndays=NDAYS, roll_days=7);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # USA

# %%
ecdc.plot_country('US', log=LOG_PLOT,ndays=NDAYS, roll_days=7);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Germany

# %%
ecdc.plot_country('DE', log=LOG_PLOT,ndays=NDAYS, roll_days=7);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## UK

# %%
ecdc.plot_country('UK', log=LOG_PLOT,ndays=NDAYS,roll_days=7);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # China

# %%
plot_country('CN', log=LOG_PLOT);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Commit and Push

# %%
# %cd Documents/code/covid19/
now = datetime.now()
commit_message = "Last run on " + now.strftime('%Y-%m-%d %H:%M')
commit_message
! echo $commit_message > commit_message.txt
! git add .
! git commit -F commit_message.txt
! git push
# Out:
# [Errno 2] No such file or directory: 'Documents/code/covid19/'
# /home/gythaogg/Documents/code/covid19/notebooks
# [feature/angular e5b31e4] Last run on 2020-10-13 13:33
#  2 files changed, 28 insertions(+), 22 deletions(-)
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 16 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 815 bytes | 815.00 KiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To github.com:gythaogg/covid19.git
#    cfb7930..e5b31e4  feature/angular -> feature/angular

# %%
! git push --set-upstream origin feature/angular
# Out:
# Branch 'feature/angular' set up to track remote branch 'feature/angular' from 'origin'.
# Everything up-to-date
