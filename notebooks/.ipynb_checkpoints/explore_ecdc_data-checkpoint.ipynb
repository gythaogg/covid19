# %% [markdown]
# # Setup

# %%
LOG_PLOT = False

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
plt.style.use('seaborn-darkgrid')
import os
from helper import *
df = ecdc()
df_at = at()
def country_name(geoId):
    return df[df.geoId==geoId].iloc[0].countriesAndTerritories.replace('_', ' ')

print(df.columns)
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp',
#        'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'],
#       dtype='object')

# %% [markdown]
# ## ECDC Data

# %%
def plot_selection(selection, roll_days=7, log=False):   
    f,ax = plt.subplots()
    ax.plot(selection.dateRep, selection['cases'].rolling(roll_days).mean(), label=f'{roll_days} day average', marker='o', markersize=4, linestyle='--')
#     ax.xaxis.set_major_locator(plt.MaxNLocator(20))
    ax.xaxis.set_major_locator(plt.MaxNLocator(20))

    plt.xticks(rotation=45)
    ax.bar(selection.dateRep, selection['cases'],label='recorded',  alpha=0.6, color='C1')
    plt.legend(loc='best')
    if log:
        plt.yscale('log')
        
    plt.title(selection.iloc[0].countriesAndTerritories.replace('_', ' '))
    plt.tight_layout()

    return f

def plot_comparison(geoIds, roll_days=7, log=False, ndays=30):
    f,ax = plt.subplots(figsize=(9,6))
    for geoId in geoIds:
        selection = select_country(geoId, ndays)
        ax.plot(selection.dateRep, selection['Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'], 
                label=country_name(geoId))

    ax.xaxis.set_major_locator(plt.MaxNLocator(25))
    ax.yaxis.set_major_locator(plt.MaxNLocator(10))

    plt.xticks(rotation=45)
    if log:
        plt.yscale('log')
        
    plt.legend(loc='best')
    plt.title('Cumulative number for 14 days of COVID-19 cases per 100000')
    plt.tight_layout()

def select_country(geoId, ndays=0):
    if not ndays:
        selection = df[df.geoId==geoId].sort_values(by=['year','month','day'], ascending=True)
    else:
        selection = df[df.geoId==geoId].sort_values(by=['year','month','day'], ascending=True).tail(ndays)
        
    return selection

def plot_country(geoId, **kwargs):
    return plot_selection(select_country(geoId), **kwargs)

# %% [markdown]
# ## Austria - from Gesundheitsminesterium

# %%
def plot_Austria(roll_days=7, log=False):
    df = at()
    f,ax = plt.subplots()
    ax.plot(df.time, df['tägliche Erkrankungen'].rolling(roll_days).mean(), label=f'{roll_days} day average', marker='o', markersize=4, linestyle='--')
    ax.xaxis.set_major_locator(plt.MaxNLocator(20))
    plt.xticks(rotation=45)
    ax.bar(df.time, df['tägliche Erkrankungen'],label='recorded',  alpha=0.6, color='C1')
    plt.legend(loc='best')
    plt.title('Positive COVID tests')
    if log:
        plt.yscale('log')
    plt.tight_layout()
    return f

# %% [markdown]
# ## DF Subsets

# %%
SELECTION =  df[df.geoId.isin(['AT', 'IN', 'US', 'UK', 'DE', 'IT', 'NL'])]
EU = df[df.continentExp=='Europe']
AMERICA = df[(df.continentExp=='America')]

# %% [markdown]
# # Comparison per 100,000 of the population

# %%
# countries = ['AT', 'IN', 'US', 'UK', 'DE', 'NL', 'FR',  'IT', 'ES','EL' ]
countries = ('AT', 'IN', 'US', 'UK')
plot_comparison(countries, log=False, ndays=500)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# ## Sweden and the world

# %%
countries = ('SE', 'ES','FR','UK','DE','AT','IT','NO','DK','FI')
plot_comparison(countries, log=False, ndays=500)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# # Overview

# %% [markdown]
# ## Selected Countries

# %%
overview(SELECTION, compact=False)
# Out:
#                                cases                                     \
#                          rolling_avg                        last_5_days
# countriesAndTerritories
# India                          73155  74442, 61267, 72049, 78524, 70496
# United_States_of_America       46969  34901, 40705, 43062, 48182, 56800
# United_Kingdom                 14520  22961, 12593, 14542, 14162, 17540
# Netherlands                     4523       4000, 4572, 4517, 4979, 5813
# Italy                           2998       2578, 2257, 2677, 3677, 4458
# Germany                         2895       1382, 2639, 2828, 4058, 4516
# Austria                          898          599, 1268, 549, 947, 1221
#
#                                  deaths                              \
#                             max     sum last_7_days_sum rolling_avg
# countriesAndTerritories
# India                     97894  106490            6717         960
# United_States_of_America  78427  212773            4965         709
# United_Kingdom            22961   42592             390          56
# Netherlands                5813    6522             112          16
# Italy                      6557   36083             165          24
# Germany                    6294    9589              81          12
# Austria                    1268     853              51           7
#
#                                                          \
#                                       last_5_days   max
# countriesAndTerritories
# India                     903, 884, 986, 971, 964  2003
# United_States_of_America  400, 398, 717, 892, 972  4928
# United_Kingdom                 33, 19, 76, 70, 77  1224
# Netherlands                      5, 7, 21, 36, 13   234
# Italy                          18, 16, 28, 31, 22   971
# Germany                         5, 12, 16, 16, 11   315
# Austria                            4, 5, 22, 4, 9    31
#
#                          Cumulative_number_for_14_days_of_COVID-19_cases_per_100000  \
#                                                                              latest
# countriesAndTerritories
# India                                                             79.593594
# United_States_of_America                                         190.897591
# United_Kingdom                                                   218.242015
# Netherlands                                                      304.336905
# Italy                                                             56.453374
# Germany                                                           41.480759
# Austria                                                          128.200569
#
#
#                                  max
# countriesAndTerritories
# India                      94.173835
# United_States_of_America  282.723242
# United_Kingdom            218.242015
# Netherlands               304.336905
# Italy                     124.025121
# Germany                    86.358323
# Austria                   128.200569

# %% [markdown]
# ## Most cases in the last 7 days

# %% [markdown]
# ### Europe

# %%
overview(EU, compact=True).head(5)
# Out:
#                               cases               deaths                  \
#                         rolling_avg latest    max    sum last_7_days_sum
# countriesAndTerritories
# United_Kingdom                14520  17540  22961  42592             390
# France                        13448  18129  18746  32521             502
# Russia                        10697  11493  11656  22056            1165
# Spain                          9960  12423  31785  32688             715
# Ukraine                        5111   5397   8702   4690             497
#
#
#                         rolling_avg latest   max
# countriesAndTerritories
# United_Kingdom                   56     77  1224
# France                           72     76  2004
# Russia                          166    191   312
# Spain                           102    126  1179
# Ukraine                          71     93   129

# %% [markdown]
# ### America

# %%
overview(AMERICA).head(5)
# Out:
#                                cases                deaths                  \
#                          rolling_avg latest    max     sum last_7_days_sum
# countriesAndTerritories
# United_States_of_America       46969  56800  78427  212773            4965
# Brazil                         25907  27750  69074  148957            4277
# Argentina                      13052  15454  17213   22710            2422
# Mexico                          8025  30468  30468   83096            5018
# Colombia                        7263   8496  13056   27331            1135
#
#
#                          rolling_avg latest   max
# countriesAndTerritories
# United_States_of_America         709    972  4928
# Brazil                           611    729  1595
# Argentina                        346    484  3351
# Mexico                           717   3013  3013
# Colombia                         162    151   400

# %% [markdown]
# ### World

# %%
overview(df).head(5)
# Out:
#                             cases                                     deaths  \
#                               sum last_7_days_sum rolling_avg latest     sum
# countriesAndTerritories
# India                     6835655          523071       74724  78524  105526
# United_States_of_America  7549794          316751       45250  48182  211801
# Brazil                    5000694          189759       27108  31553  148228
# United_Kingdom             544275           91011       13002  14162   42515
# France                     653509           89974       12853  18746   32445
#
#
#                          last_7_days_sum rolling_avg latest
# countriesAndTerritories
# India                               6848         978    971
# United_States_of_America            4873         696    892
# Brazil                              4276         611    734
# United_Kingdom                       372          53     70
# France                               489          70     80

# %% [markdown]
# ## Lowset number of new cases in the last 7 days

# %% [markdown]
# ### Europe*
#
# \*among countries with population of at least 1 million

# %%
overview(EU[EU.popData2019>1*10**7], compact=False).tail(5)
# Out:
#                           cases                                           \
#                             sum last_7_days_sum rolling_avg latest   max
# countriesAndTerritories
# Belgium                  134197           12034        1719      0  3272
# Portugal                  80312            5595         799    427  1638
# Sweden                    96145            2992         427      0  1698
# Greece                    20541            2418         345    399   460
# Azerbaijan                40931             812         116    143   590
#
#                         deaths                                          \
#                            sum last_7_days_sum rolling_avg latest  max
# countriesAndTerritories
# Belgium                  10092              76          11      3  321
# Portugal                  2032              69          10     14   60
# Sweden                    5883               3           0      0  115
# Greece                     420              32           5      3    9
# Azerbaijan                 600              10           1      2   13
#
#                         Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
#                                                                             latest
# countriesAndTerritories
# Belgium                                                         232.804817
# Portugal                                                        103.623595
# Sweden                                                           64.866862
# Greece                                                           43.013263
# Azerbaijan                                                       15.456244

# %% [markdown]
# ### America*
#
# \*among countries with population of at least 10 million

# %%
overview(AMERICA[AMERICA.popData2019>1*10**7]).tail(5)
# Out:
#                           cases                                    deaths  \
#                             sum last_7_days_sum rolling_avg latest    sum
# countriesAndTerritories
# Guatemala                 94870            3902         557    688   3310
# Dominican_Republic       115371            3471         496    317   2149
# Bolivia                  137468            2827         404    361   8156
# Cuba                       5883             352          50     38    123
# Haiti                      8838              91          13     19    229
#
#
#                         last_7_days_sum rolling_avg latest
# countriesAndTerritories
# Guatemala                            72          10      8
# Dominican_Republic                   48           7      5
# Bolivia                             225          32     27
# Cuba                                  1           0      0
# Haiti                                 0           0      0

# %% [markdown]
# ### World*
# \*among countries with population of at least 10 million

# %%
overview( df[df.popData2019>1*10**7]).tail(5)
# Out:
#                             cases                                    deaths  \
#                               sum last_7_days_sum rolling_avg latest    sum
# countriesAndTerritories
# Taiwan                        521               7           1      3      7
# Niger                        1200               4           1      0     69
# Vietnam                      1098               4           1      1     35
# Cambodia                      280               3           0      0      0
# United_Republic_of_Tanzania   509               0           0      0     21
#
#
#                             last_7_days_sum rolling_avg latest
# countriesAndTerritories
# Taiwan                                    0           0      0
# Niger                                     0           0      0
# Vietnam                                   0           0      0
# Cambodia                                  0           0      0
# United_Republic_of_Tanzania               0           0      0

# %% [markdown]
# # Austria
# Compare ECDC data with Gesundheitsminesterium Data

# %% [markdown]
# ## Plots

# %%
plot_Austria();
plot_country('AT', log=LOG_PLOT);
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Weekday bias

# %%
f, ax = plt.subplots(nrows=2, sharex=True)
df_at.groupby(['weekday']).sum()['tägliche Erkrankungen'].plot(ax=ax[0], marker='o')
ax[0].set_ylabel('Reported positive tests (Total)')
df_at.groupby(['weekday']).median()['tägliche Erkrankungen'].plot(ax=ax[1], marker='o')
ax[1].set_ylabel('Reported positive tests (Median)')
ax[1].set_xlabel('Day of the week')
ax[1].set_xticks([0,1,2,3,4,5,6])
ax[1].set_xticklabels(WEEKDAYS, rotation=40)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # India

# %%
plot_country('IN', log=LOG_PLOT);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # USA

# %%
plot_country('US', log=LOG_PLOT);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Germany

# %%
plot_country('DE', log=LOG_PLOT);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## UK

# %%
plot_country('UK', log=LOG_PLOT);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # China

# %%
plot_country('CN', log=LOG_PLOT);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Commit and Push

# %%
# %cd Documents/code/covid19/
now = datetime.now()
commit_message = "Last run on " + now.strftime('%Y-%m-%d %H:%M')
commit_message
! echo $commit_message > commit_message.txt
! git add .
! git commit -F commit_message.txt
! git push
# Out:
# [Errno 2] No such file or directory: 'Documents/code/covid19/'
# /home/gythaogg/Documents/code/covid19/notebooks
# warning: CRLF will be replaced by LF in notebooks/AT/AllgemeinDaten.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/Altersverteilung.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/AltersverteilungTodesfaelle.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/AltersverteilungTodesfaelleDemogr.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/Bezirke.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/Bundesland.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/CovidFaelle_Altersgruppe.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/CovidFaelle_GKZ.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/CovidFaelle_Timeline.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/CovidFallzahlen.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/Epikurve.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/GenesenTimeline.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/GenesenTodesFaelleBL.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/Geschlechtsverteilung.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/IBAuslastung.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/IBKapazitaeten.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/NBAuslastung.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/NBKapazitaeten.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/TodesfaelleTimeline.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/Version.csv.
# The file will have its original line endings in your working directory
# warning: CRLF will be replaced by LF in notebooks/AT/VerstorbenGeschlechtsverteilung.csv.
# The file will have its original line endings in your working directory
# [feature/angular 05df39b] Last run on 2020-10-09 14:40
#  31 files changed, 48454 insertions(+), 11783 deletions(-)
#  create mode 100644 notebooks/.ipynb_checkpoints/Austria-checkpoint.ipynb
#  delete mode 100644 notebooks/.ipynb_checkpoints/Austria_ECDC Data Differences-checkpoint.ipynb
#  rewrite notebooks/.ipynb_checkpoints/explore_ecdc_data-checkpoint.ipynb (60%)
#  create mode 100644 notebooks/AT/AllgemeinDaten.csv
#  create mode 100644 notebooks/AT/Altersverteilung.csv
#  create mode 100644 notebooks/AT/AltersverteilungTodesfaelle.csv
#  create mode 100644 notebooks/AT/AltersverteilungTodesfaelleDemogr.csv
#  create mode 100644 notebooks/AT/Bezirke.csv
#  create mode 100644 notebooks/AT/Bundesland.csv
#  create mode 100644 notebooks/AT/CovidFaelle_Altersgruppe.csv
#  create mode 100644 notebooks/AT/CovidFaelle_GKZ.csv
#  create mode 100644 notebooks/AT/CovidFaelle_Timeline.csv
#  create mode 100644 notebooks/AT/CovidFaelle_Timeline_GKZ.csv
#  create mode 100644 notebooks/AT/CovidFallzahlen.csv
#  create mode 100644 notebooks/AT/Epikurve.csv
#  create mode 100644 notebooks/AT/GenesenTimeline.csv
#  create mode 100644 notebooks/AT/GenesenTodesFaelleBL.csv
#  create mode 100644 notebooks/AT/Geschlechtsverteilung.csv
#  create mode 100644 notebooks/AT/IBAuslastung.csv
#  create mode 100644 notebooks/AT/IBKapazitaeten.csv
#  create mode 100644 notebooks/AT/NBAuslastung.csv
#  create mode 100644 notebooks/AT/NBKapazitaeten.csv
#  create mode 100644 notebooks/AT/TodesfaelleTimeline.csv
#  create mode 100644 notebooks/AT/Version.csv
#  create mode 100644 notebooks/AT/VerstorbenGeschlechtsverteilung.csv
#  create mode 100644 notebooks/AT/data.zip
#  create mode 100644 notebooks/Austria.ipynb
#  delete mode 100644 notebooks/Austria_ECDC Data Differences.ipynb
# Enumerating objects: 40, done.
# Counting objects: 100% (40/40), done.
# Delta compression using up to 16 threads
# Compressing objects: 100% (33/33), done.
# Writing objects: 100% (34/34), 1.58 MiB | 1.37 MiB/s, done.
# Total 34 (delta 6), reused 0 (delta 0)
# remote: Resolving deltas: 100% (6/6), completed with 3 local objects.
# To github.com:gythaogg/covid19.git
#    ad4ccac..05df39b  feature/angular -> feature/angular

# %%
! git push --set-upstream origin feature/angular
# Out:
# Branch 'feature/angular' set up to track remote branch 'feature/angular' from 'origin'.
# Everything up-to-date
