# %% [markdown]
# # Setup

# %%
LOG_PLOT = False
NDAYS=100

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
plt.style.use('seaborn-darkgrid')
import os
from helper import *
from datetime import datetime
from ecdc import ECDC

# %% [markdown]
# ## ECDC Data

# %%
ecdc = ECDC()
df = ecdc.df
print(ecdc.df.dateRep.max())
df.columns
# Out:
# 2020-11-16 00:00:00
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp',
#        'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'],
#       dtype='object')

# %% [markdown]
# ## DF Subsets

# %%
EU = df[df.continentExp=='Europe']
AMERICA = df[(df.continentExp=='America')]
df.columns
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp',
#        'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'],
#       dtype='object')

# %% [markdown]
# # Overview

# %%
ecdc.overview(df).head(5)
# Out:
#                             dateRep          cases  \
#                              latest    rolling_avg
# countriesAndTerritories
# United_States_of_America 2020-11-16  152201.428571
# India                    2020-11-16   41638.571429
# Italy                    2020-11-16   34775.000000
# France                   2020-11-16   27786.142857
# Brazil                   2020-11-16   26406.285714
#
#                                                                           \
#                                                      last_5_days     max
# countriesAndTerritories
# United_States_of_America  143306, 153669, 184813, 165277, 132170  184813
# India                          47905, 44879, 44684, 41100, 30548   97894
# Italy                          32961, 37977, 40902, 37249, 33977   40902
# France                         35879, 33172, 23794, 32095, 27228   86852
# Brazil                             48331, 33207, 29070, 38307, 0   69074
#
#                           deaths                               \
#                              sum last_7_days_sum  rolling_avg
# countriesAndTerritories
# United_States_of_America  246214            8642  1234.571429
# India                     130070            3459   494.142857
# Italy                      45229            3835   547.857143
# France                     44548            4109   587.000000
# Brazil                    165658            3261   465.857143
#
#                                                             \
#                                          last_5_days   max
# countriesAndTerritories
# United_States_of_America  2117, 630, 1915, 1255, 614  4928
# India                        550, 547, 520, 447, 435  2003
# Italy                        623, 636, 550, 544, 546   971
# France                       328, 425, 932, 354, 302  2004
# Brazil                         544, 908, 456, 921, 0  1595
#
#                          Cumulative_number_for_14_days_of_COVID-19_cases_per_100000  \
#                                                                              latest
# countriesAndTerritories
# United_States_of_America                                         556.029800
# India                                                             45.067769
# Italy                                                            777.331890
# France                                                           847.466897
# Brazil                                                           143.688553
#
#
#                                  max
# countriesAndTerritories
# United_States_of_America  556.029800
# India                      94.173835
# Italy                     777.331890
# France                    988.180138
# Brazil                    304.320523

# %% [markdown]
# ## Deaths

# %%
f, ax = plt.subplots()
deaths =ecdc.df.groupby('dateRep').agg({'deaths':'sum'})
ax.plot(deaths.index, deaths.deaths.rolling(14).mean(), label='total', c='k', linestyle='--')
continents = ecdc.df.continentExp.unique()
for c in continents:
    if c=='Other': continue
    df_deaths =ecdc.df[ecdc.df.continentExp==c].groupby('dateRep').agg({'deaths':'sum'})
    ax.plot(df_deaths.index, df_deaths.deaths.rolling(14).mean(), label=c.replace('_',' '))
    
    
pretty_plot(ax, log=True,title='Deaths')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Austria, USA, India, UK, Netherlands and Germany

# %% [markdown]
# ## Comparison - cumulative number for 14 days of cases per 100000

# %%
# countries = ['AT', 'IN', 'US', 'UK', 'DE', 'NL', 'FR',  'IT', 'ES','EL' ]
countries = ['AT', 'IN', 'US', 'UK', 'NL', 'DE', 'CZ','CH']
SELECTION =  ecdc.df[ecdc.df.geoId.isin(countries)]

ecdc.plot_comparison(countries, log=False, ndays=100)
ecdc.overview(SELECTION)
# Out:
# <img src="data:image/png;base64,..." width="900">
#                             dateRep          cases  \
#                              latest    rolling_avg
# countriesAndTerritories
# United_States_of_America 2020-11-16  152201.428571
# India                    2020-11-16   41638.571429
# United_Kingdom           2020-11-16   25329.285714
# Germany                  2020-11-16   18494.142857
# Austria                  2020-11-16    7283.714286
# Czechia                  2020-11-16    6469.714286
# Switzerland              2020-11-16    6432.285714
# Netherlands              2020-11-16    5394.571429
#
#                                                                           \
#                                                      last_5_days     max
# countriesAndTerritories
# United_States_of_America  143306, 153669, 184813, 165277, 132170  184813
# India                          47905, 44879, 44684, 41100, 30548   97894
# United_Kingdom                 22950, 33470, 27301, 26860, 24962   33470
# Germany                        21866, 23542, 22461, 16947, 10824   23542
# Austria                            9643, 10368, 8962, 7192, 5278   10368
# Czechia                             8925, 7870, 7355, 4199, 1887   15731
# Switzerland                               8238, 6893, 6715, 0, 0   21842
# Netherlands                         5400, 5627, 6086, 5903, 5408   11102
#
#                           deaths                               \
#                              sum last_7_days_sum  rolling_avg
# countriesAndTerritories
# United_States_of_America  246214            8642  1234.571429
# India                     130070            3459   494.142857
# United_Kingdom             51934            2890   412.857143
# Germany                    12547            1195   170.714286
# Austria                     1679             344    49.142857
# Czechia                     6208            1350   192.857143
# Switzerland                 2956             552    78.857143
# Netherlands                 8475             481    68.714286
#
#                                                             \
#                                          last_5_days   max
# countriesAndTerritories
# United_States_of_America  2117, 630, 1915, 1255, 614  4928
# India                        550, 547, 520, 447, 435  2003
# United_Kingdom               595, 563, 376, 462, 168  1224
# Germany                       215, 218, 178, 107, 62   315
# Austria                           55, 37, 64, 55, 50    64
# Czechia                      247, 185, 171, 132, 150   259
# Switzerland                         86, 98, 93, 0, 0   169
# Netherlands                       74, 89, 53, 85, 43   234
#
#                          Cumulative_number_for_14_days_of_COVID-19_cases_per_100000  \
#                                                                              latest
# countriesAndTerritories
# United_States_of_America                                         556.029800
# India                                                             45.067769
# United_Kingdom                                                   501.753174
# Germany                                                          308.723717
# Austria                                                         1042.852990
# Czechia                                                         1112.434036
# Switzerland                                                     1199.106750
# Netherlands                                                      508.605318
#
#
#                                   max
# countriesAndTerritories
# United_States_of_America   556.029800
# India                       94.173835
# United_Kingdom             501.753174
# Germany                    310.257097
# Austria                   1042.852990
# Czechia                   1594.405529
# Switzerland               1262.059328
# Netherlands                762.410353

# %% [markdown]
# ## Deaths

# %%
f,ax = plt.subplots()
countries = ('AT', 'US', 'IN', 'UK', 'NL', 'DE')
for c in countries:
    df = ecdc.select_country(c)
    popData2019 = df.iloc[0].popData2019
    label = df.iloc[0].countriesAndTerritories.replace('_',' ')

    ax.plot(df.dateRep, df.deaths.rolling(14).mean(), label=label)

pretty_plot(ax,log=False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Cases

# %%
f,ax = plt.subplots()
countries = ('AT', 'US', 'IN', 'UK', 'NL', 'DE')
for c in countries:
    df = ecdc.select_country(c)
    popData2019 = df.iloc[0].popData2019
    label = df.iloc[0].countriesAndTerritories.replace('_',' ')

    ax.plot(df.dateRep, df.cases.rolling(14).mean(), label=label)

pretty_plot(ax,log=True,title='Cases')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Sweden and the world

# %%
countries = ('SE', 'NZ','DE','AT','NO','DK','FI','NL','US', 'IS')
ecdc.plot_comparison(countries, log=True, ndays=100)
# Out:
# <img src="data:image/png;base64,..." width="900">
# <AxesSubplot:title={'center':'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'}>

# %% [markdown]
# # Europe

# %%
big_countries = ecdc.df[ecdc.df.popData2019>10**6]
ecdc.overview(big_countries).sort_values(by=('Cumulative_number_for_14_days_of_COVID-19_cases_per_100000', 'latest'), ascending=False).head(10)
# Out:
#                            dateRep         cases  \
#                             latest   rolling_avg
# countriesAndTerritories
# Switzerland             2020-11-16   6432.285714
# Czechia                 2020-11-16   6469.714286
# Austria                 2020-11-16   7283.714286
# Georgia                 2020-11-16   3165.000000
# Slovenia                2020-11-16   1411.571429
# Poland                  2020-11-16  23792.428571
# France                  2020-11-16  27786.142857
# Armenia                 2020-11-16   1488.571429
# Croatia                 2020-11-16   2422.714286
# Italy                   2020-11-16  34775.000000
#
#                                                                   deaths  \
#                                                last_5_days    max    sum
# countriesAndTerritories
# Switzerland                         8238, 6893, 6715, 0, 0  21842   2956
# Czechia                       8925, 7870, 7355, 4199, 1887  15731   6208
# Austria                      9643, 10368, 8962, 7192, 5278  10368   1679
# Georgia                       3120, 3473, 3504, 3020, 3157   3869    733
# Slovenia                       2222, 1931, 1515, 1737, 920   2612    511
# Poland                   25221, 22683, 24051, 25571, 21854  27875  10348
# France                   35879, 33172, 23794, 32095, 27228  86852  44548
# Armenia                        1993, 1703, 1472, 1482, 549   4527   1788
# Croatia                       2597, 3082, 3056, 2866, 2362   3082   1049
# Italy                    32961, 37977, 40902, 37249, 33977  40902  45229
#
#                                                                               \
#                         last_7_days_sum rolling_avg              last_5_days
# countriesAndTerritories
# Switzerland                         552   78.857143         86, 98, 93, 0, 0
# Czechia                            1350  192.857143  247, 185, 171, 132, 150
# Austria                             344   49.142857       55, 37, 64, 55, 50
# Georgia                             234   33.428571       33, 37, 33, 34, 30
# Slovenia                            129   18.428571       14, 13, 44, 19, 11
# Poland                             2476  353.714286  430, 275, 419, 546, 303
# France                             4109  587.000000  328, 425, 932, 354, 302
# Armenia                             208   29.714286       32, 29, 41, 25, 25
# Croatia                             255   36.428571       28, 32, 43, 38, 43
# Italy                              3835  547.857143  623, 636, 550, 544, 546
#
#                                \
#                           max
# countriesAndTerritories
# Switzerland               169
# Czechia                   259
# Austria                    64
# Georgia                    45
# Slovenia                   44
# Poland                    546
# France                   2004
# Armenia                    41
# Croatia                    43
# Italy                     971
#
#                         Cumulative_number_for_14_days_of_COVID-19_cases_per_100000  \
#                                                                             latest
# countriesAndTerritories
# Switzerland                                                    1199.106750
# Czechia                                                        1112.434036
# Austria                                                        1042.852990
# Georgia                                                        1007.215341
# Slovenia                                                        931.948938
# Poland                                                          877.127562
# France                                                          847.466897
# Armenia                                                         826.242305
# Croatia                                                         802.478555
# Italy                                                           777.331890
#
#
#                                  max
# countriesAndTerritories
# Switzerland              1262.059328
# Czechia                  1594.405529
# Austria                  1042.852990
# Georgia                  1007.215341
# Slovenia                 1126.575514
# Poland                    877.127562
# France                    988.180138
# Armenia                  1049.217507
# Croatia                   802.478555
# Italy                     777.331890

# %% [markdown]
# ## Fastest growing number of cases per 100,000

# %%
EU_med = EU[EU.popData2019>1000000]
EU_most = EU_med.sort_values(['dateRep', 'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'], ascending=[False,False]).head(10)

geoIds = EU_med.sort_values(['dateRep', 'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'], ascending=[False,False]).head(5).geoId.to_list()

ecdc.plot_comparison(sorted(set(['AT', *geoIds ])), log=False, ndays=45, field='Cumulative_number_for_14_days_of_COVID-19_cases_per_100000');
EU_most
# Out:
# <img src="data:image/png;base64,..." width="900">
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 49128 2020-11-16   16     11  2020      0       0             Switzerland
# 13524 2020-11-16   16     11  2020   1887     150                 Czechia
# 2976  2020-11-16   16     11  2020   5278      50                 Austria
# 19489 2020-11-16   16     11  2020   3157      30                 Georgia
# 46348 2020-11-16   16     11  2020    920      11                Slovenia
# 41079 2020-11-16   16     11  2020  21854     303                  Poland
# 18432 2020-11-16   16     11  2020  27228     302                  France
# 2102  2020-11-16   16     11  2020    549      25                 Armenia
# 12470 2020-11-16   16     11  2020   2362      43                 Croatia
# 26355 2020-11-16   16     11  2020  33977     546                   Italy
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# 49128    CH                  CHE    8544527.0       Europe
# 13524    CZ                  CZE   10649800.0       Europe
# 2976     AT                  AUT    8858775.0       Europe
# 19489    GE                  GEO    3996762.0       Europe
# 46348    SI                  SVN    2080908.0       Europe
# 41079    PL                  POL   37972812.0       Europe
# 18432    FR                  FRA   67012883.0       Europe
# 2102     AM                  ARM    2957728.0       Europe
# 12470    HR                  HRV    4076246.0       Europe
# 26355    IT                  ITA   60359546.0       Europe
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 49128                                        1199.106750
# 13524                                        1112.434036
# 2976                                         1042.852990
# 19489                                        1007.215341
# 46348                                         931.948938
# 41079                                         877.127562
# 18432                                         847.466897
# 2102                                          826.242305
# 12470                                         802.478555
# 26355                                         777.331890

# %% [markdown]
# ## Most deaths

# %%
geoIds = EU_med.sort_values(['dateRep', 'deaths'], ascending=[False,False]).head(5).geoId.to_list()
print(geoIds)
ecdc.plot_comparison(['AT', *geoIds ], log=False, ndays=200, field='deaths', roll_days=14);
# Out:
# ['IT', 'RU', 'PL', 'FR', 'UK']
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# # Commit and Push

# %%
# %cd Documents/code/covid19/
now = datetime.now()
commit_message = "Last run on " + now.strftime('%Y-%m-%d %H:%M')
commit_message
! echo $commit_message > commit_message.txt
! git add .
! git commit -F commit_message.txt
! git push

# %%
! git push --set-upstream origin feature/angular
# Out:
# Branch 'feature/angular' set up to track remote branch 'feature/angular' from 'origin'.
# Everything up-to-date
