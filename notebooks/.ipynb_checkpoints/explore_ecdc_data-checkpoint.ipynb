# %% [markdown]
# # Setup

# %%
# %matplotlib notebook
LOG_PLOT = True

# %% [markdown]
# ## Imports

# %%
from matplotlib import pyplot as plt
plt.style.use('seaborn-darkgrid')
import pandas as pd
from datetime import datetime

import requests
from json import loads, dumps

import os

# %% [markdown]
# ## ECDC Data

# %%
# WORLD
def fetch_world():
    response = requests.get('https://opendata.ecdc.europa.eu/covid19/casedistribution/json')    
    json = response.json()
    df = pd.read_json(dumps(json['records']))   
    df['dateRep']=pd.to_datetime(df['dateRep'].astype(str), format='%d/%m/%Y')

    return df



def plot_country(geoId, roll_days=7, log=False):
    selection = df[df.geoId==geoId].sort_values(by=['year','month','day'], ascending=True)

    f,ax = plt.subplots()
    ax.plot(selection.dateRep, selection['cases'].rolling(roll_days).mean(), label=f'{roll_days} day average', marker='o', markersize=4, linestyle='--')
#     ax.xaxis.set_major_locator(plt.MaxNLocator(20))
    ax.xaxis.set_major_locator(plt.MaxNLocator(20))
    plt.xticks(rotation=45)
    ax.bar(selection.dateRep, selection['cases'],label='recorded',  alpha=0.6, color='C1')
    plt.legend(loc='best')
    if log:
        plt.yscale('log')
        
    plt.title(selection.iloc[0].countriesAndTerritories.replace('_', ' '))
    plt.tight_layout()

    return f



df = fetch_world()

# %% [markdown]
# ## Austria - from Gesundheitsminesterium

# %%
# AUSTRIA
WEEKDAYS = ('Monday', 'Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday')

def fetch_Austria():
    df = pd.read_csv('https://info.gesundheitsministerium.at/data/Epikurve.csv', delimiter=';')
    weekday= []
    print(df.columns)
    for i, row in df.iterrows():
        day_num = datetime.strptime(row['time'], '%d.%m.%Y').weekday()
        weekday.append(day_num)
        
    df['weekday'] = weekday
    df['time']=pd.to_datetime(df['time'].astype(str), format='%d.%m.%Y')
#     .dt.strftime('%d/%m/%Y')

    return df

def plot_Austria(roll_days=7, log=False):
    df = fetch_Austria()
    f,ax = plt.subplots()
    ax.plot(df.time, df['tägliche Erkrankungen'].rolling(roll_days).mean(), label=f'{roll_days} day average', marker='o', markersize=4, linestyle='--')
    ax.xaxis.set_major_locator(plt.MaxNLocator(20))
    plt.xticks(rotation=45)
    ax.bar(df.time, df['tägliche Erkrankungen'],label='recorded',  alpha=0.6, color='C1')
    plt.legend(loc='best')
    plt.title('Positive COVID tests')
    if log:
        plt.yscale('log')
    plt.tight_layout()
    return f

df_at  = fetch_Austria()
# Out:
# Index(['time', 'tägliche Erkrankungen', 'Timestamp'], dtype='object')

# %% [markdown]
# ## Aggregation Functions

# %%
import numpy as np
def rolling_avg(x):
    return np.round(x.iloc[-7:].mean())

def latest(x):
    return x.iloc[-1]

def last_7_days_sum(x):
    return x.iloc[-7:].sum()

# %% [markdown]
# ## DF Subsets

# %%
SELECTION =  df[df.geoId.isin(['AT', 'IN', 'US', 'UK', 'DE', 'IT', 'NL'])]
EU = df[df.continentExp=='Europe']
AMERICA = df[(df.continentExp=='America')]

# %% [markdown]
# # Overview

# %% [markdown]
# ## Selected Countries

# %%
SELECTION.sort_values(
    by=['year','month','day'], ascending=True).groupby("countriesAndTerritories").agg(
    {'cases': ['sum', last_7_days_sum, latest, rolling_avg, 'max' ],
    'deaths': ['sum',  last_7_days_sum, latest, rolling_avg, 'max' ],} ).sort_values(by= ('cases','last_7_days_sum'),ascending=False)
# Out:
#                             cases                                            \
#                               sum last_7_days_sum latest rolling_avg    max
# countriesAndTerritories
# India                     5818570          603893  86052       86270  97894
# United_States_of_America  6978417          303959  44213       43423  78427
# United_Kingdom             416363           34749   6634        4964   6634
# Netherlands                103034           15047   2541        2150   2541
# Germany                    280223           12450   2153        1779   6294
# Italy                      304323           11298   1786        1614   6557
# Austria                     41246            4876    688         697   1141
#
#                           deaths
#                              sum last_7_days_sum latest rolling_avg   max
# countriesAndTerritories
# India                      92290            7918   1141        1131  2003
# United_States_of_America  202810            5177    901         740  4928
# United_Kingdom             41902             197     40          28  1224
# Netherlands                 6303              46     16           7   234
# Germany                     9443              65     15           9   315
# Italy                      35781             123     23          18   971
# Austria                      783              25      6           4    31

# %% [markdown]
# ## Most cases in the last 7 days

# %% [markdown]
# ### Europe

# %%
EU.sort_values(
    by=['year','month','day'], ascending=True).groupby("countriesAndTerritories").agg(
    {'cases': ['sum', last_7_days_sum, latest, rolling_avg, 'max' ],
    'deaths': ['sum',  last_7_days_sum, latest, rolling_avg, 'max' ],} ).sort_values(by= ('cases','last_7_days_sum'),ascending=False).head(10)
# Out:
#                            cases                                            \
#                              sum last_7_days_sum latest rolling_avg    max
# countriesAndTerritories
# France                    497237           81756  16096       11679  16096
# Spain                     704209           78558  10653       11223  31428
# Russia                   1128836           43555   6595        6222  11656
# United_Kingdom            416363           34749   6634        4964   6634
# Ukraine                   188106           21862   3372        3123   5863
# Netherlands               103034           15047   2541        2150   2541
# Czechia                    58374           14219   2910        2031   3123
# Germany                   280223           12450   2153        1779   6294
# Italy                     304323           11298   1786        1614   6557
# Romania                   118054            9364   1639        1338   1767
#
#                         deaths
#                            sum last_7_days_sum latest rolling_avg   max
# countriesAndTerritories
# France                   31511             416     52          59  2004
# Spain                    31118             713     84         102  1179
# Russia                   19948             887    149         127   312
# United_Kingdom           41902             197     40          28  1224
# Ukraine                   3757             357     52          51   129
# Netherlands               6303              46     16           7   234
# Czechia                    567              78     12          11    24
# Germany                   9443              65     15           9   315
# Italy                    35781             123     23          18   971
# Romania                   4591             279     41          40    60

# %% [markdown]
# ### America

# %%
AMERICA.sort_values(
    by=['year','month','day'], ascending=True).groupby("countriesAndTerritories").agg(
    {'cases': ['sum', last_7_days_sum, latest, rolling_avg, 'max' ],
    'deaths': ['sum',  last_7_days_sum, latest, rolling_avg, 'max' ],} ).sort_values(by= ('cases','last_7_days_sum'),ascending=False).head(10)
# Out:
#                             cases                                            \
#                               sum last_7_days_sum latest rolling_avg    max
# countriesAndTerritories
# United_States_of_America  6978417          303959  44213       43423  78427
# Brazil                    4657702          202316  32817       28902  69074
# Argentina                  678266           89267  13467       12752  17213
# Colombia                   790823           46878   6555        6697  13056
# Peru                       788930           38832   6235        5547  10143
# Mexico                     715457           31344   5408        4478   9556
# Chile                      451634           10484   1731        1498  36179
# Ecuador                    131146            8889   1254        1270  11536
# Costa_Rica                  69459            8641   1400        1234   1897
# Canada                     149094            8227   1341        1175   2760
#
#                           deaths
#                              sum last_7_days_sum latest rolling_avg   max
# countriesAndTerritories
# United_States_of_America  202810            5177    901         740  4928
# Brazil                    139808            4873    831         696  1595
# Argentina                  14766            2537    390         362   573
# Colombia                   24924            1259    178         180   400
# Peru                       31938             792     68         113  3935
# Mexico                     75439            3260    490         466  1091
# Chile                      12469             327    124          47  1057
# Ecuador                    11213             184     42          26  3800
# Costa_Rica                   795             129     14          18    39
# Canada                      9249              49      6           7   222

# %% [markdown]
# ### World

# %%
df.sort_values(
    by=['year','month','day'], ascending=True).groupby("countriesAndTerritories").agg(
    {'cases': ['sum', last_7_days_sum, latest, rolling_avg, 'max' ],
    'deaths': ['sum',  last_7_days_sum, latest, rolling_avg, 'max' ],} ).sort_values(by= ('cases','last_7_days_sum'),ascending=False).head(10)
# Out:
#                             cases                                            \
#                               sum last_7_days_sum latest rolling_avg    max
# countriesAndTerritories
# India                     5818570          603893  86052       86270  97894
# United_States_of_America  6978417          303959  44213       43423  78427
# Brazil                    4657702          202316  32817       28902  69074
# Argentina                  678266           89267  13467       12752  17213
# France                     497237           81756  16096       11679  16096
# Spain                      704209           78558  10653       11223  31428
# Colombia                   790823           46878   6555        6697  13056
# Russia                    1128836           43555   6595        6222  11656
# Peru                       788930           38832   6235        5547  10143
# Israel                     214458           37525   9768        5361  11316
#
#                           deaths
#                              sum last_7_days_sum latest rolling_avg   max
# countriesAndTerritories
# India                      92290            7918   1141        1131  2003
# United_States_of_America  202810            5177    901         740  4928
# Brazil                    139808            4873    831         696  1595
# Argentina                  14766            2537    390         362   573
# France                     31511             416     52          59  2004
# Spain                      31118             713     84         102  1179
# Colombia                   24924            1259    178         180   400
# Russia                     19948             887    149         127   312
# Peru                       31938             792     68         113  3935
# Israel                      1378             209     53          30    71

# %% [markdown]
# ## Lowset number of new cases in the last 7 days

# %% [markdown]
# ### Europe*
#
# \*among countries with population of at least 1 million

# %%
selection = EU[EU.popData2019>1*10**6]
selection.sort_values(
    by=['year','month','day'], ascending=True).groupby("countriesAndTerritories").agg(
    {'cases': ['sum', last_7_days_sum, latest, rolling_avg, 'max' ],
    'deaths': ['sum',  last_7_days_sum, latest, rolling_avg, 'max' ],} ).sort_values(by= ('cases','last_7_days_sum'),ascending=False).tail(10)
# Out:
#                          cases                                         deaths  \
#                            sum last_7_days_sum latest rolling_avg  max    sum
# countriesAndTerritories
# North_Macedonia          17200             926    151         132  403    712
# Azerbaijan               39686             909    162         130  590    581
# Norway                   13275             776    123         111  425    270
# Slovenia                  4816             758    122         108  137    135
# Finland                   9379             580     91          83  267    343
# Lithuania                 4070             566    138          81  138     89
# Serbia                   33163             468     83          67  467    745
# Kosovo                   15333             451     63          64  496    616
# Estonia                   3076             298     43          43  134     64
# Latvia                    1594             100     22          14   71     36
#
#
#                         last_7_days_sum latest rolling_avg max
# countriesAndTerritories
# North_Macedonia                      37      2           5  16
# Azerbaijan                           10      1           1  13
# Norway                                4      3           1  13
# Slovenia                              4      2           1   6
# Finland                               4      0           1  43
# Lithuania                             2      2           0   6
# Serbia                                7      1           1  18
# Kosovo                                9      0           1  40
# Estonia                               0      0           0   6
# Latvia                                0      0           0   4

# %% [markdown]
# ### America*
#
# \*among countries with population of at least 10 million

# %%
selection = AMERICA[AMERICA.popData2019>1*10**7]
selection.sort_values(
    by=['year','month','day'], ascending=True).groupby("countriesAndTerritories").agg(
    {'cases': ['sum', last_7_days_sum, latest, rolling_avg, 'max' ],
    'deaths': ['sum',  last_7_days_sum, latest, rolling_avg, 'max' ],} ).sort_values(by= ('cases','last_7_days_sum'),ascending=False).tail(10)
# Out:
#                           cases                                            \
#                             sum last_7_days_sum latest rolling_avg    max
# countriesAndTerritories
# Mexico                   715457           31344   5408        4478   9556
# Chile                    451634           10484   1731        1498  36179
# Ecuador                  131146            8889   1254        1270  11536
# Canada                   149094            8227   1341        1175   2760
# Venezuela                 70406            6122    967         875   2133
# Guatemala                 87933            4269    491         610   4233
# Dominican_Republic       110122            3986    385         569   2147
# Bolivia                  132618            3199    628         457   2687
# Cuba                       5310             377     40          54     93
# Haiti                      8646              90      0          13    284
#
#                         deaths
#                            sum last_7_days_sum latest rolling_avg   max
# countriesAndTerritories
# Mexico                   75439            3260    490         466  1091
# Chile                    12469             327    124          47  1057
# Ecuador                  11213             184     42          26  3800
# Canada                    9249              49      6           7   222
# Venezuela                  581              60      7           9    17
# Guatemala                 3170             134     16          19    74
# Dominican_Republic        2076              54      2           8    39
# Bolivia                   7765             254     34          36  1610
# Cuba                       118               9      0           1     6
# Haiti                      225               5      0           1    12

# %% [markdown]
# ### World*
# \*among countries with population of at least 10 million

# %%
selection = df[df.popData2019>1*10**7]
selection.sort_values(
    by=['year','month','day'], ascending=True).groupby("countriesAndTerritories").agg(
    {'cases': ['sum', last_7_days_sum, latest, rolling_avg, 'max' ],
    'deaths': ['sum',  last_7_days_sum, latest, rolling_avg, 'max' ],} ).sort_values(by= ('cases','last_7_days_sum'),ascending=True).head(10)
# Out:
#                             cases                                          \
#                               sum last_7_days_sum latest rolling_avg  max
# countriesAndTerritories
# United_Republic_of_Tanzania   509               0      0           0  174
# Cambodia                      275               0      0           0   35
# Vietnam                      1069               3      0           0   50
# Burundi                       477               4      1           1   40
# Taiwan                        509               6      0           1   31
# Yemen                        2033              10      1           1  116
# Niger                        1194              14      1           2   69
# Thailand                     3519              22      3           3  263
# Malawi                       5747              36      1           5  192
# Benin                        2325              45      0           6  139
#
#                             deaths
#                                sum last_7_days_sum latest rolling_avg max
# countriesAndTerritories
# United_Republic_of_Tanzania     21               0      0           0   6
# Cambodia                         0               0      0           0   0
# Vietnam                         35               0      0           0   4
# Burundi                          1               0      0           0   1
# Taiwan                           7               0      0           0   3
# Yemen                          587               3      0           0  52
# Niger                           69               0      0           0   5
# Thailand                        59               1      0           0   4
# Malawi                         179               0      0           0  12
# Benin                           40               0      0           0   3

# %% [markdown]
# # Austria
# Compare ECDC data with Gesundheitsminesterium Data

# %% [markdown]
# ### Total number of cases

# %%
df_at['tägliche Erkrankungen'].sum(), df[df.geoId=='AT'].cases.sum()
# Out:
# (41552, 41246)

# %% [markdown]
# ## Gesundheitsministerium vs. ECDC (Discrepancy!)

# %%
f,ax = plt.subplots()
# ax.bar(df_at.time, df_at['tägliche Erkrankungen'],label='recorded',  alpha=0.6, color='C1')

ax.plot(df_at.time, df_at['tägliche Erkrankungen'].rolling(7).mean(),  marker='o', markersize=4, linestyle='--', color='C1')

ax.bar(df_at.time, df_at['tägliche Erkrankungen'],label='AT',  alpha=0.6, color='C1')
selection = df[df.geoId=='AT'].sort_values(by=['year','month','day'], ascending=True)
ax.bar(selection.dateRep, selection['cases'],label='ECDH',  alpha=0.6, color='C0')
ax.plot(selection.dateRep, selection['cases'].rolling(7).mean(), marker='o', markersize=4, linestyle='--',color='C0')
# plt.yscale('log')

ax.xaxis.set_major_locator(plt.MaxNLocator(20));

plt.xticks(rotation=45);
plt.legend(loc='best')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Weekday bias

# %%
f, ax = plt.subplots(nrows=2, sharex=True)
df_at.groupby(['weekday']).sum()['tägliche Erkrankungen'].plot(ax=ax[0], marker='o')
ax[0].set_ylabel('Reported positive tests (Total)')
df_at.groupby(['weekday']).median()['tägliche Erkrankungen'].plot(ax=ax[1], marker='o')
ax[1].set_ylabel('Reported positive tests (Median)')
ax[1].set_xlabel('Day of the week')
ax[1].set_xticks([0,1,2,3,4,5,6])
ax[1].set_xticklabels(WEEKDAYS, rotation=40)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # India

# %%
plot_country('IN', log=LOG_PLOT);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # USA

# %%
plot_country('US', log=LOG_PLOT);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Germany

# %%
plot_country('DE', log=LOG_PLOT);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## UK

# %%
plot_country('UK', log=LOG_PLOT);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # China

# %%
plot_country('CN', log=LOG_PLOT);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Commit and Push

# %%
# %cd Documents/code/covid19/
now = datetime.now()
commit_message = "Last run on " + now.strftime('%Y-%m-%d %H:%M')
commit_message
! echo $commit_message > commit_message.txt
! git add .
! git commit -F commit_message.txt
! git push
# Out:
# [Errno 2] No such file or directory: 'Documents/code/covid19/'
# /home/gythaogg/Documents/code/covid19/notebooks
# [develop 1240865] Last run on 2020-09-25 16:32
#  2 files changed, 28 insertions(+), 16 deletions(-)
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 16 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 887 bytes | 887.00 KiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To github.com:gythaogg/covid19.git
#    fe322b7..1240865  develop -> develop
