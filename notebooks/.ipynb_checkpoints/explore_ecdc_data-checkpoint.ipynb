# %% [markdown]
# # Setup

# %%
LOG_PLOT = False
NDAYS=100

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
plt.style.use('seaborn-darkgrid')
import os
from helper import *
from datetime import datetime
from ecdc import ECDC

# %% [markdown]
# ## ECDC Data

# %%
ecdc = ECDC()
df = ecdc.df
print(ecdc.df.dateRep.max())
df.columns
# Out:
# 2020-10-23 00:00:00
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp',
#        'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'],
#       dtype='object')

# %% [markdown]
# ## DF Subsets

# %%
EU = df[df.continentExp=='Europe'].groupby('dateRep', as_index=False).agg({'cases': sum})
AMERICA = df[(df.continentExp=='America')]

# %%
ecdc.plot_selection(EU, ndays=250, roll_days=7, log=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:title={'center':'Positive COVID tests'}>

# %% [markdown]
# # Overview

# %% [markdown]
# ## Austria, USA, India, ...

# %%
# countries = ['AT', 'IN', 'US', 'UK', 'DE', 'NL', 'FR',  'IT', 'ES','EL' ]
countries = ('AT', 'IN', 'US', 'UK', 'NL', 'DE', )
SELECTION =  df[df.geoId.isin(countries)]

ecdc.plot_comparison(countries, log=False, ndays=100)
ecdc.overview(SELECTION)
# Out:
# <img src="data:image/png;base64,..." width="900">
#                                  cases                                     \
#                            rolling_avg                        last_5_days
# countriesAndTerritories
# United_States_of_America  61207.857143  47843, 60160, 58549, 62978, 72058
# India                     55834.857143  55722, 46790, 54044, 55839, 54366
# United_Kingdom            19549.285714  16981, 18803, 21330, 26687, 21238
# Netherlands                8342.428571       8439, 7720, 8149, 8738, 9268
# Germany                    7819.142857     4325, 6868, 7595, 11287, 11242
# Austria                    1796.428571       1062, 1054, 1803, 2355, 2570
#
#                                  deaths                              \
#                             max     sum last_7_days_sum rolling_avg
# countriesAndTerritories
# United_States_of_America  78427  223042            5342  763.142857
# India                     97894  117306            5145  735.000000
# United_Kingdom            26687   44347            1054  150.571429
# Netherlands                9268    6909             226   32.285714
# Germany                   11287    9954             220   31.428571
# Austria                    2570     957              63    9.000000
#
#                                                           \
#                                        last_5_days   max
# countriesAndTerritories
# United_States_of_America  385, 459, 933, 1135, 841  4928
# India                      579, 587, 717, 702, 690  2003
# United_Kingdom               67, 80, 241, 191, 189  1224
# Netherlands                      23, 8, 45, 59, 46   234
# Germany                         12, 47, 39, 30, 49   315
# Austria                            3, 9, 8, 13, 17    31
#
#                          Cumulative_number_for_14_days_of_COVID-19_cases_per_100000  \
#                                                                              latest
# countriesAndTerritories
# United_States_of_America                                         243.643718
# India                                                             62.584155
# United_Kingdom                                                   373.087434
# Netherlands                                                      616.120795
# Germany                                                          106.759624
# Austria                                                          234.072995
#
#
#                                  max
# countriesAndTerritories
# United_States_of_America  282.723242
# India                      94.173835
# United_Kingdom            373.087434
# Netherlands               616.120795
# Germany                   106.759624
# Austria                   234.072995

# %% [markdown]
# ## Sweden and the world

# %%
countries = ('SE', 'NZ','DE','AT','IT','NO','DK','FI','IS','BE')
ecdc.plot_comparison(countries, log=False, ndays=100)
# Out:
# <img src="data:image/png;base64,..." width="900">
# <AxesSubplot:title={'center':'Cumulative number for 14 days of COVID-19 cases per 100000'}>

# %% [markdown]
# ### World

# %%
ecdc.overview(df).head(5)
# Out:
#                                  cases                                     \
#                            rolling_avg                        last_5_days
# countriesAndTerritories
# United_States_of_America  61207.857143  47843, 60160, 58549, 62978, 72058
# India                     55834.857143  55722, 46790, 54044, 55839, 54366
# France                    27051.285714  29837, 13243, 20468, 26676, 41622
# Brazil                    22034.857143  10982, 15383, 23227, 24818, 24858
# United_Kingdom            19549.285714  16981, 18803, 21330, 26687, 21238
#
#                                  deaths                              \
#                             max     sum last_7_days_sum rolling_avg
# countriesAndTerritories
# United_States_of_America  78427  223042            5342  763.142857
# India                     97894  117306            5145  735.000000
# France                    41622   34210            1085  155.000000
# Brazil                    69074  155900            3440  491.428571
# United_Kingdom            26687   44347            1054  150.571429
#
#                                                           \
#                                        last_5_days   max
# countriesAndTerritories
# United_States_of_America  385, 459, 933, 1135, 841  4928
# India                      579, 587, 717, 702, 690  2003
# France                      85, 146, 262, 163, 162  2004
# Brazil                     230, 271, 661, 566, 497  1595
# United_Kingdom               67, 80, 241, 191, 189  1224
#
#                          Cumulative_number_for_14_days_of_COVID-19_cases_per_100000  \
#                                                                              latest
# countriesAndTerritories
# United_States_of_America                                         243.643718
# India                                                             62.584155
# France                                                           488.570235
# Brazil                                                           139.865753
# United_Kingdom                                                   373.087434
#
#
#                                  max
# countriesAndTerritories
# United_States_of_America  282.723242
# India                      94.173835
# France                    488.570235
# Brazil                    304.320523
# United_Kingdom            373.087434

# %% [markdown]
# # Austria

# %% [markdown]
# ## Plots

# %%
ecdc.plot_country('AT', log=True, ndays=NDAYS, roll_days=7);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # India

# %%
ecdc.plot_country('IN', log=LOG_PLOT,ndays=200, roll_days=7);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # USA

# %%
ecdc.plot_country('US', log=LOG_PLOT,ndays=150, roll_days=7);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Germany

# %%
ecdc.plot_country('DE', log=LOG_PLOT,ndays=NDAYS, roll_days=7);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## UK

# %%
ecdc.plot_country('UK', log=LOG_PLOT,ndays=NDAYS,roll_days=7);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Commit and Push

# %%
# %cd Documents/code/covid19/
now = datetime.now()
commit_message = "Last run on " + now.strftime('%Y-%m-%d %H:%M')
commit_message
! echo $commit_message > commit_message.txt
! git add .
! git commit -F commit_message.txt
! git push
# Out:
# [Errno 2] No such file or directory: 'Documents/code/covid19/'
# /home/gythaogg/Documents/code/covid19/notebooks
# [feature/angular d79cb9f] Last run on 2020-10-21 19:58
#  2 files changed, 116 insertions(+), 136 deletions(-)
# Enumerating objects: 11, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 16 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 276.41 KiB | 4.61 MiB/s, done.
# Total 6 (delta 5), reused 0 (delta 0)
# remote: Resolving deltas: 100% (5/5), completed with 4 local objects.
# To github.com:gythaogg/covid19.git
#    2f73c29..d79cb9f  feature/angular -> feature/angular

# %%
! git push --set-upstream origin feature/angular
# Out:
# Branch 'feature/angular' set up to track remote branch 'feature/angular' from 'origin'.
# Everything up-to-date
